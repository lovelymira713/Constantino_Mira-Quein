# %%
import pandas as pd
import matplotlib.pyplot as plt ml ml

# google resource initialization
url = 'https://drive.google.com/file/d/1QkoBcQhR9zVZq44SM1zziROXZGiDPhlv/view?usp=sharing'
file_id=url.split('/')[-2]
dwn_url='https://drive.google.com/uc?id=' + file_id

# read the dataset
dataset = pd.read_csv(dwn_url)
dataset.head()
# Out:
#       location iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG  2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  total_boosters  daily_vaccinations_raw  \
# 0                      NaN             NaN                     NaN
# 1                      NaN             NaN                     NaN
# 2                      NaN             NaN                     NaN
# 3                      NaN             NaN                     NaN
# 4                      NaN             NaN                     NaN
#
#    daily_vaccinations  total_vaccinations_per_hundred  \
# ...

# %%
udw import pandas as pd
import matplotlib.pyplot as plt

# 5 countries lang
countries = ['United States', 'China', 'Philippines', 'Malaysia', 'Vietnam']
df = dataset[dataset['location'].isin(countries)]

# kunin latest data para di mag doble
df = df.sort_values('date')
df = df.groupby('location').tail(1)


fig, ax = plt.subplots(1, 3, figsize=(15,5))
fig.suptitle('COVID-19 Vaccination Comparison')

# chart 1
ax[0].bar(df['location'], df['people_vaccinated'])
ax[0].set_title('People Vaccinated')
ax[0].tick_params(axis='x', rotation=90)
ooo9# chart 2
ax[1].bar(df['location'], df['vs j.mnnpeople_fully_va.,ccinated'])
ax[1].set_title('Fully Vaccinated')
ax[1].tick_params(axis='x', rotation=90)

# chart 3
ax[2].bar(df['location'], df['total_boosters'])
ax[2].set_title('Total Boosters')
ax[2].tick_params(axis='x', rotation=90)

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# filter yung 5 countries
countries = ['United States', 'China', 'Philippines', 'Malaysia', 'Vietnam']
df = dataset[dataset['location'].isin(countries)]

#latest data ng bawat country
df = df.sort_values('date')
df = df.groupby('location').tail(1)

# bar graph ng total_vaccinations
plt.figure(figsize=(10,5))
plt.bar(df['location'], df['total_vaccinations'])
plt.title('Total Vaccinations: US, China, PH, Malaysia, Vietnam')
plt.ylabel('Total Vaccinations')
plt.xlabel('Country')
plt.xticks(rotation=90)
plt.show()
